# %%
import pandas as pd

# %%
list1 = [1,3,5]

# %%
ser1 = pd.Series(list1)

# %%
ser1
# Out:
# 0    1
# 1    3
# 2    5
# dtype: int64

# %%
import numpy as np

# %%
data = np.array([1,2,3,4,5])

# %%
type(data)
# Out:
# numpy.ndarray

# %%
ser2 = pd.Series(data)

# %%
ser2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
ser1[:2]
# Out:
# 0    1
# 1    3
# dtype: int64

# %%
ser_1 = pd.Series(list1,index = ['one','two','three'])

# %%
ser_1
# Out:
# one      1
# two      3
# three    5
# dtype: int64

# %%
ser_1['three']
# Out:
# 5

# %%
ser_1[:'three']
# Out:
# one      1
# two      3
# three    5
# dtype: int64

# %%
ser_1>40
# Out:
# one      False
# two      False
# three    False
# dtype: bool

# %%
ser_1[ser_1>2]
# Out:
# two      3
# three    5
# dtype: int64

# %%
ser_1.min()
# Out:
# 1

# %%
ser_1.max()
# Out:
# 5

# %%
ser_1[(ser_1>2)&(ser_1<3)]
# Out:
# Series([], dtype: int64)

# %%
ser_1+10
# Out:
# one      11
# two      13
# three    15
# dtype: int64

# %%
ser_1*10
# Out:
# one      10
# two      30
# three    50
# dtype: int64

# %%
data = {'Ram':40,'anju':55,'anu':39,'manu':47}

# %%
marks=pd.Series(data)

# %%
marks
# Out:
# Ram     40
# anju    55
# anu     39
# manu    47
# dtype: int64

# %%
name = ['anju','manju','rinu','varun','Ram']

# %%
marks = pd.Series(data,index=name)

# %%
marks
# Out:
# anju     55.0
# manju     NaN
# rinu      NaN
# varun     NaN
# Ram      40.0
# dtype: float64

# %%
marks.isna()
# Out:
# anju     False
# manju     True
# rinu      True
# varun     True
# Ram      False
# dtype: bool

# %%
marks[marks.isna()]
# Out:
# manju   NaN
# rinu    NaN
# varun   NaN
# dtype: float64

# %%
marks.notna()
# Out:
# anju      True
# manju    False
# rinu     False
# varun    False
# Ram       True
# dtype: bool

# %%
marks[marks.notna()]
# Out:
# anju    55.0
# Ram     40.0
# dtype: float64

# %%
data = {'Name':['Ram','Varun','Manu','Anu'],'Age':[20,21,22,21],'marks1':[96,95,80,85],'marks2':[90,93,87,86]}

# %%
mark_sheet=pd.DataFrame(data)

# %%
mark_sheet
# Out:
#     Name  Age  marks1  marks2
# 0    Ram   20      96      90
# 1  Varun   21      95      93
# 2   Manu   22      80      87
# 3    Anu   21      85      86

# %%
mark_sheet['Age']
# Out:
# 0    20
# 1    21
# 2    22
# 3    21
# Name: Age, dtype: int64

# %%
mark_sheet1=pd.DataFrame(data,columns=['Name','Age','marks1','marks2','city'])

# %%
mark_sheet1
# Out:
#     Name  Age  marks1  marks2 city
# 0    Ram   20      96      90  NaN
# 1  Varun   21      95      93  NaN
# 2   Manu   22      80      87  NaN
# 3    Anu   21      85      86  NaN

# %%
mark_sheet1['city']=['Mumbai','Delhi','Kochi','Tvm']

# %%
mark_sheet1
# Out:
#     Name  Age  marks1  marks2    city
# 0    Ram   20      96      90  Mumbai
# 1  Varun   21      95      93   Delhi
# 2   Manu   22      80      87   Kochi
# 3    Anu   21      85      86     Tvm

# %%
mark_sheet1['Total_marks']=mark_sheet1['marks1']+mark_sheet1['marks2']

# %%
mark_sheet1
# Out:
#     Name  Age  marks1  marks2    city  Total_marks
# 0    Ram   20      96      90  Mumbai          186
# 1  Varun   21      95      93   Delhi          188
# 2   Manu   22      80      87   Kochi          167
# 3    Anu   21      85      86     Tvm          171

# %%
del mark_sheet1['Total_marks']

# %%
mark_sheet1
# Out:
#     Name  Age  marks1  marks2    city
# 0    Ram   20      96      90  Mumbai
# 1  Varun   21      95      93   Delhi
# 2   Manu   22      80      87   Kochi
# 3    Anu   21      85      86     Tvm

# %%
mark_sheet1=mark_sheet1.drop('city',axis=1) ##inplace= true used after axis and skiping lhs part

# %%
mark_sheet1
# Out:
#     Name  Age  marks1  marks2
# 0    Ram   20      96      90
# 1  Varun   21      95      93
# 2   Manu   22      80      87
# 3    Anu   21      85      86

# %%
df = pd.read_csv(r'E:\auto-mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# ...

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.tail(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 388  26.0          4         156.0         92    2585          14.5
# 389  22.0          6         232.0        112    2835          14.7
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 392  27.0          4         151.0         90    2950          17.3
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                    car name
# 388          82       1  chrysler lebaron medallion
# 389          82       1              ford granada l
# 390          82       3            toyota celica gt
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.shape
# Out:
# (398, 9)

# %%
df.shape[0]
# Out:
# 398

# %%
df.shape[1]
# Out:
# 9

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.sort_values(by='mpg')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 103  11.0          8         400.0        150    4997          14.0
# 124  11.0          8         350.0        180    3664          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df.sort_values(by='mpg',ascending=False)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
# ..    ...        ...           ...        ...     ...           ...
# 103  11.0          8         400.0        150    4997          14.0
# 67   11.0          8         429.0        208    4633          11.0
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 28    9.0          8         304.0        193    4732          18.5
#
#      model year  origin              car name
# 322          80       3             mazda glc
# 329          80       3   honda civic 1500 gl
# ...

# %%
df.sort_values(by=['mpg','cylinders'])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 27   11.0          8         318.0        210    4382          13.5
# 67   11.0          8         429.0        208    4633          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df.sort_values(by=['cylinders','mpg'])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 111  18.0          3          70.0         90    2124          13.5
# 71   19.0          3          70.0         97    2330          13.5
# 243  21.5          3          80.0        110    2720          13.5
# 334  23.7          3          70.0        100    2420          12.5
# 76   18.0          4         121.0        112    2933          14.5
# ..    ...        ...           ...        ...     ...           ...
# 165  20.0          8         262.0        110    3221          13.5
# 251  20.2          8         302.0        139    3570          12.8
# 298  23.0          8         350.0        125    3900          17.4
# 300  23.9          8         260.0         90    3420          22.2
# 364  26.6          8         350.0        105    3725          19.0
#
#      model year  origin                           car name
# 111          73       3                          maxda rx3
# ...

# %%
df.sort_values(by=['mpg','cylinders'],ascending=[True,False])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 27   11.0          8         318.0        210    4382          13.5
# 67   11.0          8         429.0        208    4633          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df[['mpg','horsepower','weight']]
# Out:
#       mpg horsepower  weight
# 0    18.0        130    3504
# 1    15.0        165    3693
# 2    18.0        150    3436
# 3    16.0        150    3433
# 4    17.0        140    3449
# ..    ...        ...     ...
# 393  27.0         86    2790
# 394  44.0         52    2130
# 395  32.0         84    2295
# 396  28.0         79    2625
# 397  31.0         82    2720
#
# [398 rows x 3 columns]

# %%
df['mpg']>30
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394     True
# 395     True
# 396    False
# 397     True
# Name: mpg, Length: 398, dtype: bool

# %%
m1= df['mpg']>30

# %%
df[m1]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 53   31.0          4          71.0         65    1773          19.0
# 54   35.0          4          72.0         69    1613          18.0
# 129  31.0          4          79.0         67    1950          19.0
# 131  32.0          4          71.0         65    1836          21.0
# 144  31.0          4          76.0         52    1649          16.5
# ..    ...        ...           ...        ...     ...           ...
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin             car name
# 53           71       3  toyota corolla 1200
# 54           71       3          datsun 1200
# ...

# %%
df['weight']/1000
# Out:
# 0      3.504
# 1      3.693
# 2      3.436
# 3      3.433
# 4      3.449
#        ...
# 393    2.790
# 394    2.130
# 395    2.295
# 396    2.625
# 397    2.720
# Name: weight, Length: 398, dtype: float64

# %%
df['weight_ton'] = df['weight']/1000

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name  weight_ton
# 0       1  chevrolet chevelle malibu       3.504
# 1       1          buick skylark 320       3.693
# 2       1         plymouth satellite       3.436
# 3       1              amc rebel sst       3.433
# 4       1                ford torino       3.449

# %%
df['mpg'].min()
# Out:
# 9.0

# %%
df['mpg'].count()
# Out:
# 398

# %%
df['mpg'].quantile(0.25)
# Out:
# 17.5

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin  weight_ton
# count  398.000000  398.000000  398.000000
# mean    76.010050    1.572864    2.970425
# std      3.697627    0.802055    0.846842
# min     70.000000    1.000000    1.613000
# 25%     73.000000    1.000000    2.223750
# 50%     76.000000    1.000000    2.803500
# ...

# %%
df.describe(include='object')
# Out:
#        horsepower    car name
# count         398         398
# unique         94         305
# top           150  ford pinto
# freq           22           6

# %%
df['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
df['cylinders'].nunique()
# Out:
# 5

# %%
df['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
df.loc[:,]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  weight_ton
# 0            70       1  chevrolet chevelle malibu       3.504
# ...

# %%
df.loc[:,'mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df.loc[2,'mpg']
# Out:
# 18.0

# %%
df.loc[2,]
# Out:
# mpg                           18.0
# cylinders                        8
# displacement                 318.0
# horsepower                     150
# weight                        3436
# acceleration                  11.0
# model year                      70
# origin                           1
# car name        plymouth satellite
# weight_ton                   3.436
# Name: 2, dtype: object

# %%
df.loc[2:10,]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
#
#     model year  origin             car name  weight_ton
# 2           70       1   plymouth satellite       3.436
# 3           70       1        amc rebel sst       3.433
# 4           70       1          ford torino       3.449
# 5           70       1     ford galaxie 500       4.341
# ...

# %%
df.loc[2:10,'mpg']
# Out:
# 2     18.0
# 3     16.0
# 4     17.0
# 5     15.0
# 6     14.0
# 7     14.0
# 8     14.0
# 9     15.0
# 10    15.0
# Name: mpg, dtype: float64

# %%
df.loc[2:10,'mpg':'weight']
# Out:
#      mpg  cylinders  displacement horsepower  weight
# 2   18.0          8         318.0        150    3436
# 3   16.0          8         304.0        150    3433
# 4   17.0          8         302.0        140    3449
# 5   15.0          8         429.0        198    4341
# 6   14.0          8         454.0        220    4354
# 7   14.0          8         440.0        215    4312
# 8   14.0          8         455.0        225    4425
# 9   15.0          8         390.0        190    3850
# 10  15.0          8         383.0        170    3563

# %%
df.loc[2:10,['mpg','displacement','weight']]
# Out:
#      mpg  displacement  weight
# 2   18.0         318.0    3436
# 3   16.0         304.0    3433
# 4   17.0         302.0    3449
# 5   15.0         429.0    4341
# 6   14.0         454.0    4354
# 7   14.0         440.0    4312
# 8   14.0         455.0    4425
# 9   15.0         390.0    3850
# 10  15.0         383.0    3563

# %%
df.loc[2:10,[0,4,7]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.loc[2:10,[0,4,7]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:924, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
df.iloc[2:10,[0,4,7]]
# Out:
#     mpg  weight  origin
# 2  18.0    3436       1
# 3  16.0    3433       1
# 4  17.0    3449       1
# 5  15.0    4341       1
# 6  14.0    4354       1
# 7  14.0    4312       1
# 8  14.0    4425       1
# 9  15.0    3850       1

# %%
df.iloc[[100,200,300],[0,4,7]]
# Out:
#       mpg  weight  origin
# 100  18.0    3021       1
# 200  18.0    3574       1
# 300  23.9    3420       1

# %%
df.sample(frac=0.2)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 273  23.9          4         119.0         97    2405          14.9
# 28    9.0          8         304.0        193    4732          18.5
# 198  33.0          4          91.0         53    1795          17.4
# 10   15.0          8         383.0        170    3563          10.0
# 168  23.0          4         140.0         83    2639          17.0
# ..    ...        ...           ...        ...     ...           ...
# 379  36.0          4          98.0         70    2125          17.3
# 378  38.0          4         105.0         63    2125          14.7
# 240  30.5          4          97.0         78    2190          14.1
# 315  24.3          4         151.0         90    3003          20.1
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                car name  weight_ton
# 273          78       3           datsun 200-sx       2.405
# ...
